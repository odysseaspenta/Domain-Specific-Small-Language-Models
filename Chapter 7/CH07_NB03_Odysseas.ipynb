# %% [markdown]
# # Benchmarking Python Code Generation with Vanilla and 8-bit Quantized StarCoder2 Models
# This notebook is a companion of chapter 6 of the "Domain Specific LLMs in Action" book, author Guglielmo Iozzia, [Manning Publications](https://www.manning.com/), 2024.
# The code in this notebook is to benchmark inference performance (latency and throughtput) when generating Python code using a vanilla [StarCoder2](https://huggingface.co/Salesforce/codegen-350M-mono) 2B model, and after 8-bit quantization of the same model. It reuqires hardware acceleration.
# More details about the code can be found in the related book's chapter.

# %% [markdown]
# Install the missing requirements in the ColabVM (only HF's Optimum for the ONNX runtime and Bitsandbytes).

# %%
# !pip install optimum[onnxruntime-gpu]
# !pip install bitsandbytes
# Out:
# Collecting optimum[onnxruntime-gpu]
#   Downloading optimum-2.1.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: transformers>=4.29 in /usr/local/lib/python3.12/dist-packages (from optimum[onnxruntime-gpu]) (5.0.0)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.12/dist-packages (from optimum[onnxruntime-gpu]) (2.10.0+cu128)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from optimum[onnxruntime-gpu]) (26.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optimum[onnxruntime-gpu]) (2.0.2)
# Requirement already satisfied: huggingface_hub>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from optimum[onnxruntime-gpu]) (1.8.0)
# Collecting optimum-onnx[onnxruntime-gpu] (from optimum[onnxruntime-gpu])
#   Downloading optimum_onnx-0.1.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum[onnxruntime-gpu]) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.11->optimum[onnxruntime-gpu]) (1.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.29->optimum[onnxruntime-gpu]) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.29->optimum[onnxruntime-gpu]) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.29->optimum[onnxruntime-gpu]) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.29->optimum[onnxruntime-gpu]) (0.7.0)
# Collecting transformers>=4.29 (from optimum[onnxruntime-gpu])
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.2 MB/s eta 0:00:00
# Collecting onnx (from optimum-onnx[onnxruntime-gpu]; extra == "onnxruntime-gpu"->optimum[onnxruntime-gpu])
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Collecting onnxruntime-gpu>=1.18.0 (from optimum-onnx[onnxruntime-gpu]; extra == "onnxruntime-gpu"->optimum[onnxruntime-gpu])
#   Downloading onnxruntime_gpu-1.24.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Collecting huggingface_hub>=0.8.0 (from optimum[onnxruntime-gpu])
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers>=4.29->optimum[onnxruntime-gpu]) (2.32.4)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu>=1.18.0->optimum-onnx[onnxruntime-gpu]; extra == "onnxruntime-gpu"->optimum[onnxruntime-gpu]) (25.12.19)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu>=1.18.0->optimum-onnx[onnxruntime-gpu]; extra == "onnxruntime-gpu"->optimum[onnxruntime-gpu]) (5.29.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11->optimum[onnxruntime-gpu]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11->optimum[onnxruntime-gpu]) (3.0.3)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx->optimum-onnx[onnxruntime-gpu]; extra == "onnxruntime-gpu"->optimum[onnxruntime-gpu]) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.29->optimum[onnxruntime-gpu]) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.29->optimum[onnxruntime-gpu]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.29->optimum[onnxruntime-gpu]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.29->optimum[onnxruntime-gpu]) (2026.2.25)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub>=0.8.0->optimum[onnxruntime-gpu]) (0.1.2)
# Downloading optimum-2.1.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 16.0 MB/s eta 0:00:00
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 159.9 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 48.8 MB/s eta 0:00:00
# Downloading onnxruntime_gpu-1.24.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (252.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 MB 7.2 MB/s eta 0:00:00
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 134.7 MB/s eta 0:00:00
# Downloading optimum_onnx-0.1.0-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.2/194.2 kB 25.2 MB/s eta 0:00:00
# Installing collected packages: onnxruntime-gpu, onnx, huggingface_hub, transformers, optimum, optimum-onnx
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.8.0
#     Uninstalling huggingface_hub-1.8.0:
#       Successfully uninstalled huggingface_hub-1.8.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed huggingface_hub-0.36.2 onnx-1.21.0 onnxruntime-gpu-1.24.4 optimum-2.1.0 optimum-onnx-0.1.0 transformers-4.57.6
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.10.0+cu128)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (26.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3,>=2.3->bitsandbytes) (1.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 42.8 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.49.2

# %% [markdown]
# Upgrade the Numpy and HF's Transformers packages to the latest version. A restart of the VM is needed after.

# %%
#!pip install -U numpy transformers

# %% [markdown]
# ### Vanilla Model

# %% [markdown]
# Download the StarCoder2-3B model (in bfloat16) and its tokenizer from the HF's Hub.

# %%
from transformers import AutoTokenizer

model_id = "bigcode/starcoder2-3b"
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/958 [00:00<?, ?B/s]

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torch
from transformers import AutoModelForCausalLM

device = "cuda" if torch.cuda.is_available() else "cpu"
model = AutoModelForCausalLM.from_pretrained(model_id,
                                             device_map='auto',
                                             torch_dtype=torch.bfloat16)
model.eval()
# Out:
# config.json:   0%|          | 0.00/700 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/12.1G [00:00<?, ?B/s]
# Starcoder2ForCausalLM(
#   (model): Starcoder2Model(
#     (embed_tokens): Embedding(49152, 3072)
#     (layers): ModuleList(
#       (0-29): 30 x Starcoder2DecoderLayer(
#         (self_attn): Starcoder2Attention(
#           (q_proj): Linear(in_features=3072, out_features=3072, bias=True)
#           (k_proj): Linear(in_features=3072, out_features=256, bias=True)
#           (v_proj): Linear(in_features=3072, out_features=256, bias=True)
#           (o_proj): Linear(in_features=3072, out_features=3072, bias=True)
#         )
#         (mlp): Starcoder2MLP(
#           (c_fc): Linear(in_features=3072, out_features=12288, bias=True)
#           (c_proj): Linear(in_features=12288, out_features=3072, bias=True)
#           (act): GELUTanh()
#         )
#         (input_layernorm): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#     (rotary_emb): Starcoder2RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=3072, out_features=49152, bias=False)
# )

# %% [markdown]
# Set a text prompt (a Python function header) to be used across benchmarks.

# %%
prompt = "def print_hello_world():"

# %% [markdown]
# The code in the following cell is just to verify that model and tokenizer have been downloaded properly. You can skip its execution.

# %%
inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
outputs = model.generate(inputs)
print(tokenizer.decode(outputs[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# def print_hello_world():
#     print("Hello World")
#
# def print_hello_world_with_name(name

# %% [markdown]
# Setup a Transformers' pipeline for inference with the vanilla model.

# %%
from transformers import pipeline

pipe = pipeline("text-generation",
            model=model,
            tokenizer=tokenizer,
            do_sample=True,
            use_cache=True,
            temperature=0.2,
            top_p=0.95,
            max_length=14
)
# Out:
# Device set to use cuda:0

# %% [markdown]
# Test the pipeline.

# %%
result = pipe(prompt)
print(result[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# def print_hello_world():
#     print("Hello World")

# %% [markdown]
# Save the checkpoints locally, to be reused when quantizing it later.

# %%
checkpoint_save_dir = 'local-pt-checkpoint'
tokenizer.save_pretrained(checkpoint_save_dir)
model.save_pretrained(checkpoint_save_dir)

# %% [markdown]
# Define some utils for benchmarking (more details about them in chapter 6 of the book).

# %%
from contextlib import contextmanager
from dataclasses import dataclass
from time import perf_counter

@contextmanager
def track_infer_time(time_buffer):
    start_time = perf_counter()
    yield
    end_time = perf_counter()

    time_buffer.append(end_time - start_time)

@dataclass
class BenchmarkInferenceResult:
    model_inference_time: [int]
    optimized_model_path: str

# %% [markdown]
# Define a custom funtion to be reused across benchmarks with the different versions of the model under evaluation.

# %%
from tqdm import trange

def benchmark_inference(providers_dict, pipe, prompt, results):
  for device, label in PROVIDERS:
      for _ in trange(10, desc="Warming up"):
          pipe(prompt)

      time_buffer = []
      for _ in trange(100, desc=f"Tracking inference time ({label})"):
        with track_infer_time(time_buffer):
            pipe(prompt)

      results[label] = BenchmarkInferenceResult(
          time_buffer,
          None
      )

  return results

# %% [markdown]
# Execute the benchmarks for the StarCoder2 vanilla model.

# %%
results = {}
PROVIDERS = {
    ("gpu", "PyTorch GPU"),
}
results = benchmark_inference(PROVIDERS, pipe, prompt, results)
# Out:
# Warming up:   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Warming up:
/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (PyTorch GPU):  98%|█████████▊| 98/100 [00:20<00:00,  4.80it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (PyTorch GPU):  99%|█████████▉| 99/100 [00:20<00:00,  4.81it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (PyTorch GPU): 100%|██████████| 100/100 [00:21<00:00,  4.75it/s]

# %% [markdown]
# ### 8-bit Quantization

# %% [markdown]
# To prevent potential out of memory issues, let's do some VRAM and RAM cleanup.

# %%
import gc

model.cpu()
del model
del pipe
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# Do 8-bit quantization of the original model and save it to disk.

# %%
from transformers import BitsAndBytesConfig

quantization_config = BitsAndBytesConfig(load_in_8bit=True)

tokenizer = AutoTokenizer.from_pretrained(checkpoint_save_dir)
quantized_model = AutoModelForCausalLM.from_pretrained(checkpoint_save_dir,
                                        quantization_config=quantization_config)
quantized_model.eval()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Starcoder2ForCausalLM(
#   (model): Starcoder2Model(
#     (embed_tokens): Embedding(49152, 3072)
#     (layers): ModuleList(
#       (0-29): 30 x Starcoder2DecoderLayer(
#         (self_attn): Starcoder2Attention(
#           (q_proj): Linear8bitLt(in_features=3072, out_features=3072, bias=True)
#           (k_proj): Linear8bitLt(in_features=3072, out_features=256, bias=True)
#           (v_proj): Linear8bitLt(in_features=3072, out_features=256, bias=True)
#           (o_proj): Linear8bitLt(in_features=3072, out_features=3072, bias=True)
#         )
#         (mlp): Starcoder2MLP(
#           (c_fc): Linear8bitLt(in_features=3072, out_features=12288, bias=True)
#           (c_proj): Linear8bitLt(in_features=12288, out_features=3072, bias=True)
#           (act): GELUTanh()
#         )
#         (input_layernorm): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#     (rotary_emb): Starcoder2RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=3072, out_features=49152, bias=False)
# )

# %% [markdown]
# The code in the following cell is just to verify that model and tokenizer have been downloaded properly. You can skip its execution.

# %%
inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
outputs = quantized_model.generate(inputs)
print(tokenizer.decode(outputs[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# def print_hello_world():
#     print("Hello World!")
#
# def print_hello_world_with_name(name

# %%
quantized_model.save_pretrained('local-8bit-checkpoint')

# %%
checkpoint_8bit_save_dir = 'local-8bit-checkpoint'

# Load the quantized model from the specified directory
quantized_model_loaded = AutoModelForCausalLM.from_pretrained(checkpoint_8bit_save_dir)
quantized_model_loaded.eval()
# Out:
# Starcoder2ForCausalLM(
#   (model): Starcoder2Model(
#     (embed_tokens): Embedding(49152, 3072)
#     (layers): ModuleList(
#       (0-29): 30 x Starcoder2DecoderLayer(
#         (self_attn): Starcoder2Attention(
#           (q_proj): Linear8bitLt(in_features=3072, out_features=3072, bias=True)
#           (k_proj): Linear8bitLt(in_features=3072, out_features=256, bias=True)
#           (v_proj): Linear8bitLt(in_features=3072, out_features=256, bias=True)
#           (o_proj): Linear8bitLt(in_features=3072, out_features=3072, bias=True)
#         )
#         (mlp): Starcoder2MLP(
#           (c_fc): Linear8bitLt(in_features=3072, out_features=12288, bias=True)
#           (c_proj): Linear8bitLt(in_features=12288, out_features=3072, bias=True)
#           (act): GELUTanh()
#         )
#         (input_layernorm): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (norm): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#     (rotary_emb): Starcoder2RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=3072, out_features=49152, bias=False)
# )

# %% [markdown]
# Setup the pipeline for inference with the quantized model.

# %%
pipe = pipeline("text-generation",
            model=quantized_model_loaded,
            tokenizer=tokenizer,
            do_sample=True,
            use_cache=True,
            temperature=0.2,
            top_p=0.95,
            max_length=14,
)
# Out:
# Device set to use cuda:0

# %% [markdown]
# Verify that the pipeline works as expected.

# %%
result = pipe(prompt)
result
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': 'def print_hello_world():\n    print("Hello World")\n'}]

# %% [markdown]
# Repeat the benchmark on the quantized model.

# %%
PROVIDERS = {
    ("ort", "Quant GPU"),
}
results = benchmark_inference(PROVIDERS, pipe, prompt, results)
# Out:
# Warming up:   0%|          | 0/10 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Warming up:  10%|█         | 1/10 [00:00<00:08,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Warming up:  20%|██        | 2/10 [00:01<00:07,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Warming up:  30%|███       | 3/10 [00:02<00:06,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Warming up:  40%|████      | 4/10 [00:03<00:05,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Warming up:  50%|█████     | 5/10 [00:04<00:04,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Warming up:  60%|██████    | 6/10 [00:05<00:03,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Warming up:  70%|███████   | 7/10 [00:06<00:02,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Warming up:  80%|████████  | 8/10 [00:07<00:01,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Warming up:  90%|█████████ | 9/10 [00:08<00:00,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Warming up: 100%|██████████| 10/10 [00:09<00:00,  1.02it/s]
# Tracking inference time (Quant GPU):   0%|          | 0/100 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):   1%|          | 1/100 [00:00<01:37,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):   2%|▏         | 2/100 [00:01<01:37,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):   3%|▎         | 3/100 [00:02<01:36,  1.00it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):   4%|▍         | 4/100 [00:03<01:34,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):   5%|▌         | 5/100 [00:04<01:33,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):   6%|▌         | 6/100 [00:05<01:32,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):   7%|▋         | 7/100 [00:06<01:31,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):   8%|▊         | 8/100 [00:07<01:30,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):   9%|▉         | 9/100 [00:08<01:29,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  10%|█         | 10/100 [00:09<01:28,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  11%|█         | 11/100 [00:10<01:28,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  12%|█▏        | 12/100 [00:11<01:27,  1.00it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  13%|█▎        | 13/100 [00:12<01:27,  1.00s/it]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  14%|█▍        | 14/100 [00:13<01:26,  1.00s/it]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  15%|█▌        | 15/100 [00:14<01:24,  1.00it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  16%|█▌        | 16/100 [00:15<01:23,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  17%|█▋        | 17/100 [00:16<01:22,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  18%|█▊        | 18/100 [00:17<01:20,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  19%|█▉        | 19/100 [00:18<01:19,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  20%|██        | 20/100 [00:19<01:19,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  21%|██        | 21/100 [00:20<01:18,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  22%|██▏       | 22/100 [00:21<01:16,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  23%|██▎       | 23/100 [00:22<01:15,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  24%|██▍       | 24/100 [00:23<01:14,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  25%|██▌       | 25/100 [00:24<01:14,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  26%|██▌       | 26/100 [00:25<01:12,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  27%|██▋       | 27/100 [00:26<01:11,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  28%|██▊       | 28/100 [00:27<01:10,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  29%|██▉       | 29/100 [00:28<01:09,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  30%|███       | 30/100 [00:29<01:08,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  31%|███       | 31/100 [00:30<01:07,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  32%|███▏      | 32/100 [00:31<01:06,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  33%|███▎      | 33/100 [00:32<01:05,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  34%|███▍      | 34/100 [00:33<01:04,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  35%|███▌      | 35/100 [00:34<01:03,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  36%|███▌      | 36/100 [00:35<01:02,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  37%|███▋      | 37/100 [00:36<01:01,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  38%|███▊      | 38/100 [00:37<01:01,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  39%|███▉      | 39/100 [00:38<01:00,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  40%|████      | 40/100 [00:39<00:59,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  41%|████      | 41/100 [00:40<00:58,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  42%|████▏     | 42/100 [00:41<00:57,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  43%|████▎     | 43/100 [00:42<00:56,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  44%|████▍     | 44/100 [00:43<00:55,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  45%|████▌     | 45/100 [00:44<00:54,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  46%|████▌     | 46/100 [00:45<00:53,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  47%|████▋     | 47/100 [00:46<00:52,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  48%|████▊     | 48/100 [00:47<00:51,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  49%|████▉     | 49/100 [00:48<00:51,  1.00s/it]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  50%|█████     | 50/100 [00:49<00:49,  1.00it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  51%|█████     | 51/100 [00:50<00:49,  1.00s/it]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  52%|█████▏    | 52/100 [00:51<00:47,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  53%|█████▎    | 53/100 [00:52<00:46,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  54%|█████▍    | 54/100 [00:53<00:45,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  55%|█████▌    | 55/100 [00:54<00:44,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  56%|█████▌    | 56/100 [00:55<00:42,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  57%|█████▋    | 57/100 [00:56<00:41,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  58%|█████▊    | 58/100 [00:57<00:40,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  59%|█████▉    | 59/100 [00:58<00:39,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  60%|██████    | 60/100 [00:59<00:39,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  61%|██████    | 61/100 [01:00<00:38,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  62%|██████▏   | 62/100 [01:01<00:37,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  63%|██████▎   | 63/100 [01:01<00:36,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  64%|██████▍   | 64/100 [01:02<00:35,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  65%|██████▌   | 65/100 [01:03<00:34,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  66%|██████▌   | 66/100 [01:04<00:33,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  67%|██████▋   | 67/100 [01:05<00:32,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  68%|██████▊   | 68/100 [01:06<00:31,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  69%|██████▉   | 69/100 [01:07<00:30,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  70%|███████   | 70/100 [01:08<00:29,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  71%|███████   | 71/100 [01:09<00:28,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  72%|███████▏  | 72/100 [01:10<00:27,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  73%|███████▎  | 73/100 [01:11<00:26,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  74%|███████▍  | 74/100 [01:12<00:25,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  75%|███████▌  | 75/100 [01:13<00:24,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  76%|███████▌  | 76/100 [01:14<00:23,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  77%|███████▋  | 77/100 [01:15<00:22,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  78%|███████▊  | 78/100 [01:16<00:21,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  79%|███████▉  | 79/100 [01:17<00:20,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  80%|████████  | 80/100 [01:18<00:19,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  81%|████████  | 81/100 [01:19<00:18,  1.01it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  82%|████████▏ | 82/100 [01:20<00:17,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  83%|████████▎ | 83/100 [01:21<00:16,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  84%|████████▍ | 84/100 [01:22<00:15,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  85%|████████▌ | 85/100 [01:23<00:14,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  86%|████████▌ | 86/100 [01:24<00:13,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  87%|████████▋ | 87/100 [01:25<00:12,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  88%|████████▊ | 88/100 [01:26<00:11,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  89%|████████▉ | 89/100 [01:27<00:10,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  90%|█████████ | 90/100 [01:28<00:09,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  91%|█████████ | 91/100 [01:29<00:08,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  92%|█████████▏| 92/100 [01:30<00:07,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  93%|█████████▎| 93/100 [01:31<00:06,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  94%|█████████▍| 94/100 [01:32<00:05,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  95%|█████████▌| 95/100 [01:33<00:04,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  96%|█████████▌| 96/100 [01:34<00:03,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  97%|█████████▋| 97/100 [01:35<00:02,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  98%|█████████▊| 98/100 [01:36<00:01,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU):  99%|█████████▉| 99/100 [01:37<00:00,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Tracking inference time (Quant GPU): 100%|██████████| 100/100 [01:38<00:00,  1.02it/s]

# %% [markdown]
# ### Results of the Benchmarks

# %% [markdown]
# Visually compare the average inference times across benchmarks for the 2 different versions of the model.

# %%
import numpy as np
import plotly.express as px

# Compute average inference time
time_results = {k: np.mean(v.model_inference_time) * 1e3 for k, v in results.items()}

fig = px.bar(x=time_results.keys(), y=time_results.values(),
             title="Average inference time (ms) for each provider",
             labels={'x':'Provider', 'y':'Avg Inference time (ms)'},
             text_auto='.2s')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c23f7406-5a0b-4d29-82d4-7f2ad2e0cb50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c23f7406-5a0b-4d29-82d4-7f2ad2e0cb50")) {                    Plotly.newPlot(                        "c23f7406-5a0b-4d29-82d4-7f2ad2e0cb50",                        [{"alignmentgroup":"True","hovertemplate":"Provider=%{x}\u003cbr\u003eAvg Inference time (ms)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["PyTorch GPU","Quant GPU"],"xaxis":"x","y":[209.6767494399819,981.9917125200072],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"s ...

# %% [markdown]
# Calculate latency and throughput metrics for the 3 benchmark sets and put them into a Pandas DataFrame.

# %%
time_results = {k: np.mean(v.model_inference_time) * 1e3 for k, v in results.items()}
time_results_std = {k: np.std(v.model_inference_time) * 1000 for k, v in results.items()}

# %%
perf_results = {}
for k, v in results.items():
  latency_list = v.model_inference_time
  latency_50 = np.percentile(latency_list, 50) * 1e3
  latency_75 = np.percentile(latency_list, 75) * 1e3
  latency_90 = np.percentile(latency_list, 90) * 1e3
  latency_95 = np.percentile(latency_list, 95) * 1e3
  latency_99 = np.percentile(latency_list, 99) * 1e3

  average_latency = np.mean(v.model_inference_time) * 1e3
  throughput = 1 * (1000 / average_latency)

  perf_results[k] = (
        average_latency,
        latency_50,
        latency_75,
        latency_90,
        latency_95,
        latency_99,
        throughput,
    )

# %%
import pandas as pd

index_labels = ['Average_latency (ms)', 'Latency_P50', 'Latency_P75',
                'Latency_P90', 'Latency_P95', 'Latency_P99', 'Throughput']
perf_df = pd.DataFrame(data=perf_results, index=index_labels)
perf_df
# Out:
#                       PyTorch GPU    Quant GPU
# Average_latency (ms)   209.676749   981.991713
# Latency_P50            209.214450   980.536691
# Latency_P75            211.096354   985.076006
# Latency_P90            213.387056  1000.668823
# Latency_P95            214.999690  1004.850718
# Latency_P99            218.554223  1013.147496
# Throughput               4.769246     1.018339

# %% [markdown]
# Visually compare inference durations across benchmarks for the 2 different versions of the model.

# %%
results_df = pd.DataFrame(columns=['Provider', 'Inference_time'])
for k, v in results.items():
  for i in range(len(v.model_inference_time)):
    results_df.loc[len(results_df.index)] = [k, v.model_inference_time[i] * 1e3]

fig = px.box(results_df, x="Provider", y="Inference_time",
             points="all",
             labels={'Provider':'Provider', 'Inference_time':'Inference durations (ms)'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="756aaf09-81b6-4c6d-a073-7e703d5fc80e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("756aaf09-81b6-4c6d-a073-7e703d5fc80e")) {                    Plotly.newPlot(                        "756aaf09-81b6-4c6d-a073-7e703d5fc80e",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Provider=%{x}\u003cbr\u003eInference durations (ms)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","PyTorch GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU","Quant GPU"],"x0":" ","xaxis":"x","y":[207.09042699991187,205.9439869999551,207.54930700013574,211.76079799988656,210.2471279999918,215.08895099987058,212.07021999998688,210.4109420001805,211.91925399989486,209.05973600019934,217.730821999794,214.6101519997501,214.15773200033072,212.5852180001857,210.6079300001511,210.8855589999621,209.96482700002161,209.36248699990756,209.20718000024863,210.64646900003936,209.6782059998077,209.1843930002142,211.2365990001308,209.382278999783,210.05712800024412,209.31670899972232,208.75867700033268,209.32057900017753,20 ...
